# %%
import pandas as pd
df = pd.read_csv('dataframe.csv', sep=',')
df. drop (columns=df. columns [0], axis= 1 , inplace= True )
df
# Out:
#                                                ссылка  цена     агенство  \
# 0     https://mahachkala.cian.ru/rent/flat/287248550/  3000  Собственник
# 1     https://mahachkala.cian.ru/rent/flat/287104371/  2000  Собственник
# 2     https://mahachkala.cian.ru/rent/flat/287170526/  2500  Собственник
# 3     https://mahachkala.cian.ru/rent/flat/286285851/  1400            0
# 4     https://mahachkala.cian.ru/rent/flat/283955383/  3500  Собственник
# ...                                               ...   ...          ...
# 1375  https://mahachkala.cian.ru/rent/flat/273952065/  2999            0
# 1376  https://mahachkala.cian.ru/rent/flat/274860429/  2500            0
# 1377  https://mahachkala.cian.ru/rent/flat/281661559/  2700  Собственник
# 1378  https://mahachkala.cian.ru/rent/flat/285834115/  1500  Собственник
# 1379  https://mahachkala.cian.ru/rent/flat/286233679/  2000  Собственник
#
#      общая площадь жилая площадь  этаж  всего этажей  Дети  холодильник  \
# ...

# %%
df.columns #еще раз те метки, которые мы спарсили
# колонки 'холодильник', 'посудомойка','стиральная машина', 'мебель в комнатах', 'мебель на кухне','телевизор', 'интернет', 'кондиционер', 'душ', 'ванна': 1 - значит, есть в квартире, 0 - значит, в квартире этого нет
# Out:
# Index(['ссылка', 'цена', 'агенство', 'общая площадь', 'жилая площадь', 'этаж',
#        'всего этажей', 'Дети', 'холодильник', 'посудомойка',
#        'стиральная машина', 'мебель в комнатах', 'мебель на кухне',
#        'телевизор', 'интернет', 'кондиционер', 'душ', 'ванна', 'район'],
#       dtype='object')

# %%
df.dtypes #типы переменных
#обращу внимание, что изначально цена, общая площадь и жилая площадь имеют тип данных object
# Out:
# ссылка               object
# цена                 object
# агенство             object
# общая площадь        object
# жилая площадь        object
# этаж                  int64
# всего этажей          int64
# Дети                  int64
# холодильник           int64
# посудомойка           int64
# стиральная машина     int64
# мебель в комнатах     int64
# мебель на кухне       int64
# телевизор             int64
# интернет              int64
# кондиционер           int64
# душ                   int64
# ванна                 int64
# район                object
# улица                object
# dtype: object

# %%
df.shape #размер нашего датафрейма изначального
# Out:
# (1380, 20)

# %%
df = df.loc[~df['цена'].str.contains("мес")]
df
# Out:
#                                                ссылка  цена     агенство  \
# 0     https://mahachkala.cian.ru/rent/flat/287248550/  3000  Собственник
# 1     https://mahachkala.cian.ru/rent/flat/287104371/  2000  Собственник
# 2     https://mahachkala.cian.ru/rent/flat/287170526/  2500  Собственник
# 3     https://mahachkala.cian.ru/rent/flat/286285851/  1400            0
# 4     https://mahachkala.cian.ru/rent/flat/283955383/  3500  Собственник
# ...                                               ...   ...          ...
# 1375  https://mahachkala.cian.ru/rent/flat/273952065/  2999            0
# 1376  https://mahachkala.cian.ru/rent/flat/274860429/  2500            0
# 1377  https://mahachkala.cian.ru/rent/flat/281661559/  2700  Собственник
# 1378  https://mahachkala.cian.ru/rent/flat/285834115/  1500  Собственник
# 1379  https://mahachkala.cian.ru/rent/flat/286233679/  2000  Собственник
#
#      общая площадь жилая площадь  этаж  всего этажей  Дети  холодильник  \
# ...

# %%
df['цена'] = df['цена'].astype(int)
# Out:
# <ipython-input-169-fb5f4ca97b7c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['цена'] = df['цена'].astype(int)

# %%
df = (df[df['цена']!=0]) #удалила строки, где посуточная цена - 0
df
# Out:
#                                                ссылка  цена     агенство  \
# 0     https://mahachkala.cian.ru/rent/flat/287248550/  3000  Собственник
# 1     https://mahachkala.cian.ru/rent/flat/287104371/  2000  Собственник
# 2     https://mahachkala.cian.ru/rent/flat/287170526/  2500  Собственник
# 3     https://mahachkala.cian.ru/rent/flat/286285851/  1400            0
# 4     https://mahachkala.cian.ru/rent/flat/283955383/  3500  Собственник
# ...                                               ...   ...          ...
# 1375  https://mahachkala.cian.ru/rent/flat/273952065/  2999            0
# 1376  https://mahachkala.cian.ru/rent/flat/274860429/  2500            0
# 1377  https://mahachkala.cian.ru/rent/flat/281661559/  2700  Собственник
# 1378  https://mahachkala.cian.ru/rent/flat/285834115/  1500  Собственник
# 1379  https://mahachkala.cian.ru/rent/flat/286233679/  2000  Собственник
#
#      общая площадь жилая площадь  этаж  всего этажей  Дети  холодильник  \
# ...

# %%
df = df.loc[~df['общая площадь'].str.contains(",")]
df
# Out:
#                                                ссылка  цена     агенство  \
# 0     https://mahachkala.cian.ru/rent/flat/287248550/  3000  Собственник
# 1     https://mahachkala.cian.ru/rent/flat/287104371/  2000  Собственник
# 2     https://mahachkala.cian.ru/rent/flat/287170526/  2500  Собственник
# 3     https://mahachkala.cian.ru/rent/flat/286285851/  1400            0
# 4     https://mahachkala.cian.ru/rent/flat/283955383/  3500  Собственник
# ...                                               ...   ...          ...
# 1375  https://mahachkala.cian.ru/rent/flat/273952065/  2999            0
# 1376  https://mahachkala.cian.ru/rent/flat/274860429/  2500            0
# 1377  https://mahachkala.cian.ru/rent/flat/281661559/  2700  Собственник
# 1378  https://mahachkala.cian.ru/rent/flat/285834115/  1500  Собственник
# 1379  https://mahachkala.cian.ru/rent/flat/286233679/  2000  Собственник
#
#      общая площадь жилая площадь  этаж  всего этажей  Дети  холодильник  \
# ...

# %%
df['общая площадь'] = df['общая площадь'].astype(int)
# Out:
# <ipython-input-172-9cf42ea5672f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['общая площадь'] = df['общая площадь'].astype(int)

# %%
df = df.loc[~df['жилая площадь'].str.contains(",")]

# %%
df['жилая площадь'] = df['жилая площадь'].astype(int)
# Out:
# <ipython-input-174-a31792936d4d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['жилая площадь'] = df['жилая площадь'].astype(int)

# %%
df.dtypes #добились того, что общая и жилая площади, а также цена имеют тип int
# Out:
# ссылка               object
# цена                  int64
# агенство             object
# общая площадь         int64
# жилая площадь         int64
# этаж                  int64
# всего этажей          int64
# Дети                  int64
# холодильник           int64
# посудомойка           int64
# стиральная машина     int64
# мебель в комнатах     int64
# мебель на кухне       int64
# телевизор             int64
# интернет              int64
# кондиционер           int64
# душ                   int64
# ванна                 int64
# район                object
# улица                object
# dtype: object

# %%
df=df.drop(columns= "улица") #удалила улицы, так как эта информация не сильно важна для Махачкалы))

# %%
df
# Out:
#                                                ссылка  цена     агенство  \
# 0     https://mahachkala.cian.ru/rent/flat/287248550/  3000  Собственник
# 1     https://mahachkala.cian.ru/rent/flat/287104371/  2000  Собственник
# 2     https://mahachkala.cian.ru/rent/flat/287170526/  2500  Собственник
# 3     https://mahachkala.cian.ru/rent/flat/286285851/  1400            0
# 4     https://mahachkala.cian.ru/rent/flat/283955383/  3500  Собственник
# ...                                               ...   ...          ...
# 1375  https://mahachkala.cian.ru/rent/flat/273952065/  2999            0
# 1376  https://mahachkala.cian.ru/rent/flat/274860429/  2500            0
# 1377  https://mahachkala.cian.ru/rent/flat/281661559/  2700  Собственник
# 1378  https://mahachkala.cian.ru/rent/flat/285834115/  1500  Собственник
# 1379  https://mahachkala.cian.ru/rent/flat/286233679/  2000  Собственник
#
#       общая площадь  жилая площадь  этаж  всего этажей  Дети  холодильник  \
# ...

# %%
df=df[df['цена'] != 35000] #удаляю выброс
df
# Out:
#                                                ссылка  цена     агенство  \
# 0     https://mahachkala.cian.ru/rent/flat/287248550/  3000  Собственник
# 1     https://mahachkala.cian.ru/rent/flat/287104371/  2000  Собственник
# 2     https://mahachkala.cian.ru/rent/flat/287170526/  2500  Собственник
# 3     https://mahachkala.cian.ru/rent/flat/286285851/  1400            0
# 4     https://mahachkala.cian.ru/rent/flat/283955383/  3500  Собственник
# ...                                               ...   ...          ...
# 1375  https://mahachkala.cian.ru/rent/flat/273952065/  2999            0
# 1376  https://mahachkala.cian.ru/rent/flat/274860429/  2500            0
# 1377  https://mahachkala.cian.ru/rent/flat/281661559/  2700  Собственник
# 1378  https://mahachkala.cian.ru/rent/flat/285834115/  1500  Собственник
# 1379  https://mahachkala.cian.ru/rent/flat/286233679/  2000  Собственник
#
#       общая площадь  жилая площадь  этаж  всего этажей  Дети  холодильник  \
# ...

# %%
df.to_csv(r'C:\Users\murad\OneDrive\Рабочий стол\dataset_to_work_on.csv', sep=',', encoding='utf-8')

# %%
#будем работать в итоге с датафреймом размером 1069*19, так как пришлось удалить квартиры, которые в изначальном датасете в колонке "цена" показывали 0, так же было удалено 5 квартир, где значение жилой площади нецелое, так же избавилась от выброса в цене (35к)
#так же были удалены 8 строк с квартирами, которые при парсинге в столбце "цена" показывали цену за месяц (каким-то образом они оказались в страничках, где представлены квартиры, сдающиеся посуточно)
#cамыми главными признаками, по нашему мнению, являются цена, общая площадь, жилая площадь, этаж
# 0 в столбце "агентство" означает, что на сайте не представлена информация - квартира сдается от лица собственника или нет
# 0 в столбце "жилая площадь" означают, что арендодатели не указали информацию - не буду ничем заполнять, так как замена средняя/медиана может быть больше, чем общая площадь квартиры
#0 в столбце "дети" указывают, можно ли в квартире селиться с детьми
#0 в столбце "район" указывают, что арендодатель не указал район, в котором дом находится - пока непонятно, как эту информацию использовать - но пусть пока останется

# %%
#нашли для цены эти значения
print(df.цена.mean())
print(df.цена.median())
print(df.цена.mode())
print(df.цена.var())
print(df.цена.std())
print(df.цена.quantile(0.99))
# Out:
# 2592.531337698784
# 2500.0
# 0    2500
# Name: цена, dtype: int64
# 830570.6125469917
# 911.3564684287876
# 6000.0

# %%
#теперь для общей площади квартиры
print(df['общая площадь'].mean())
print(df['общая площадь'].median())
print(df['общая площадь'].mode())
print(df['общая площадь'].var())
print(df['общая площадь'].std())
print(df['общая площадь'].quantile(0.99))
# Out:
# 61.015902712815716
# 52.0
# 0    50
# Name: общая площадь, dtype: int64
# 2687.9445034212386
# 51.84539037774948
# 150.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (10,10))

df.цена.hist(bins=100, density=True);
df.цена.plot(kind='kde', linewidth=4)
plt.xlim(0, 15000)
plt.xlabel("Цена за сутки")
plt.title("Распределение значений цены");

# %%
import numpy as np #логарифмируем значения цены - чтобы выбросы сгладились
df.цена.apply(lambda x: np.log(x + 1)).hist(figsize=(20, 6));

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize = (10,10))

df['общая площадь'].hist(bins=140, density=True);
df['общая площадь'].plot(kind='kde', linewidth=4)
plt.xlim(10, 160)
plt.xlabel("Площадь")
plt.title("Распределение общей площади квартир");

# %%
df["общая площадь"].apply(lambda x: np.log(x + 1)).hist(figsize=(10, 6));

# %%
colnames = df.dtypes[df.dtypes == 'int64'].index.values
df[colnames].corr(method='pearson')
# Out:
#                        цена  общая площадь  жилая площадь      этаж  \
# цена               1.000000       0.171753       0.087670  0.167144
# общая площадь      0.171753       1.000000       0.231565  0.065649
# жилая площадь      0.087670       0.231565       1.000000 -0.028846
# этаж               0.167144       0.065649      -0.028846  1.000000
# всего этажей       0.222478       0.084575      -0.034342  0.625154
# Дети               0.053752       0.044081       0.052437  0.027575
# холодильник       -0.008405       0.002340       0.038120 -0.019465
# посудомойка        0.154088      -0.001758      -0.069706  0.021185
# стиральная машина  0.091610       0.026741       0.051770 -0.049140
# мебель в комнатах -0.025669       0.009996       0.034536 -0.031397
# мебель на кухне   -0.018256      -0.014406       0.069643  0.011895
# телевизор          0.105161       0.037182       0.007662  0.027062
# интернет           0.120682       0.048049       0.017449  0.045950
# ...

# %%
import seaborn as sns
sns.heatmap(df[colnames].corr(method='pearson'), 
            square=True, annot=True, fmt=".1f", 
            linewidths=0.1, cmap="RdBu");

# %%
sns.jointplot(x="цена", y="общая площадь", data=df, kind="reg");

# %%
sns.jointplot(x="цена", y="общая площадь", data=df, kind="kde");

# %%
plt.xlabel("Номер этажа")
plt.title("Частота этажей, на которых находится квартира, в выборке")
plt.ylabel("Плотность")

df.этаж.hist(bins=40, density=True);

# %%
plt.xlabel("Высота дома")
plt.ylabel("Плотность")
plt.title("Количество этажей в домах, в которых находится квартира, в выборке")
df['всего этажей'].hist(bins=40, density=True);

# %%
#мы будем предсказывать посуточную цену за съем квартиры на основе других признаков из датасета (от того, есть в квартире)
#гипотезы по большей части будут связаны с тем, как цена за съем квартиры связана, на каком этаже она находится (берем конкретный этаж и проверяем), сколько вообще этажей в доме, сдает ли ее собственник или посредник
#гипотеза, что средние значение значения цен по двум разным общим площадям равны
#гипотеза, что среднее значение цен по квартирам из Советского района (типа центр) и по другим известным нам районам (которые ближе к морю) выше, чем среднее значение цен по выборке (мб мы вернем даже улицы и еще проверим, стоят ли на главных улицах города квартиры дороже, чем в среднем по выборке)
